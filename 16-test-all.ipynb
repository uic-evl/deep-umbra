# %%
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
from IPython import display
import datetime
import time
from utils import *

from deep_shadow import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_built_with_cuda())

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# True

# %%
dates = ['winter', 'spring', 'summer']
zoom = 16
shadow_path = 'data/shadows/'
height_path = 'data/heights_new/'

BATCH_SIZE = 1
TILES_PER_CITY = 790 # 95% of 790 is 750. The rest 40 are used for validation
STEPS = 40000

if not os.path.exists('results/'):
    os.mkdir('results/')

# %%
lat, dat = True, True # lat, dat true as we are using data from multiple cities and testing multiple dates!!

# %%
# Case: Uniform Distribution of Latitudes

train_cities = ['aus', 'par', 'syd', 'sp', 'mex', 'la', 'chi']
test_cities = ['dc', 'nyc', 'joh', 'bue', 'bos', 'sea', 'tok']

# %%
# Training with -> different loss functions and resnet9 with and without attention

# checkpoint_names = ['_l1', '_l2', '_l1_smooth',  '_ssim_with_sobel', '_ssim_l1_smooth', '_ssim_l1', '_ssim_sobel_plus_l1']
checkpoint_names = ['_l1', '_l2', '_l1_smooth', '_ssim_l1_smooth', '_ssim_l1']
# loss_functions = [[l1_loss], [l2_loss], [l1_smooth_loss], [ssim_loss, sobel_loss], [ssim_loss, l1_smooth_loss], [ssim_loss, l1_loss], [ssim_loss, sobel_loss, l1_loss]]
loss_functions = [[l1_loss], [l2_loss], [l1_smooth_loss], [ssim_loss, l1_smooth_loss], [ssim_loss, l1_loss]]

for i in range(len(checkpoint_names)):
    tf.keras.backend.clear_session()
    # down_stack, up_stack = get_generator_arch('resnet9', attn = True) # defined in utils
    down_stack, up_stack = get_generator_arch('resnet9', attn = False) # defined in utils

    train_dataset, validation_dataset = get_train_test(
        height_path, shadow_path, train_cities, dates, zoom, TILES_PER_CITY, BATCH_SIZE, train_size =  0.95)
    
    checkpoint_name = 'uniform_cities_resnet_wo_attn_' + checkpoint_names[i]
    checkpoint_path = 'training_checkpoints_new/%s' % (checkpoint_name)

    deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=loss_functions[i], type='resnet9', attention=False, model_name=checkpoint_name)
    deep_shadow.fit(checkpoint_path, train_dataset, validation_dataset, STEPS)
# Out:
# Time taken for 1000 steps: 96.30 sec
# Step: 39k
# custom_loss_func:  0.0579253919
# gan_loss:  0.964929938
# disc_loss:  1.20173061
# ....................................................................................................

# %%
# Training with best lost function from above (ssim + sobel):
# 1. unet with attention
# 2. unet without attention
# 3. resnet9 without attention

attn = [True, False, False]
gen = ['unet', 'unet', 'resnet9']

for i in range(len(attn)):
    tf.keras.backend.clear_session()
    down_stack, up_stack = get_generator_arch(gen[i], attn = attn[i])

    train_dataset, validation_dataset = get_train_test(
        height_path, shadow_path, train_cities, dates, zoom, TILES_PER_CITY, BATCH_SIZE, train_size =  0.95)
    
    str_attn = 'attn' if attn[i] else 'wo_attn'
    str_gen = 'unet' if gen[i] == 'unet' else 'resnet'
    checkpoint_name = 'uniform_cities_' + str_gen + '_' + str_attn + '__ssim_with_sobel'
    checkpoint_path = 'training_checkpoints_new/%s' % (checkpoint_name)

    deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=[ssim_loss, sobel_loss], type=gen[i], attention=attn[i], model_name=checkpoint_name)
    deep_shadow.fit(checkpoint_path, train_dataset, validation_dataset, STEPS)

# %%
checkpoint_paths = glob.glob('training_checkpoints_new/*')
checkpoint_names = [folder.split('\\')[-1] for folder in checkpoint_paths]
checkpoint_paths = [path.replace('\\', '/') for path in checkpoint_paths]

# %%
# checkpoint_paths = checkpoint_paths[2:]
# checkpoint_names = checkpoint_names[2:]

checkpoint_paths
# Out:
# ['training_checkpoints_new/kFold',
#  'training_checkpoints_new/uniform_cities_multi_gan_attn__ssim_with_sobel',
#  'training_checkpoints_new/uniform_cities_resnet_attn__l1',
#  'training_checkpoints_new/uniform_cities_resnet_attn__l1_smooth',
#  'training_checkpoints_new/uniform_cities_resnet_attn__l2',
#  'training_checkpoints_new/uniform_cities_resnet_attn__ssim_l1',
#  'training_checkpoints_new/uniform_cities_resnet_attn__ssim_l1_smooth',
#  'training_checkpoints_new/uniform_cities_resnet_attn__ssim_sobel_plus_l1',
#  'training_checkpoints_new/uniform_cities_resnet_attn__ssim_with_sobel',
#  'training_checkpoints_new/uniform_cities_resnet_wo_attn__l1',
#  'training_checkpoints_new/uniform_cities_resnet_wo_attn__l1_smooth',
#  'training_checkpoints_new/uniform_cities_resnet_wo_attn__l2',
#  'training_checkpoints_new/uniform_cities_resnet_wo_attn__ssim_l1',
#  'training_checkpoints_new/uniform_cities_resnet_wo_attn__ssim_l1_smooth',
#  'training_checkpoints_new/uniform_cities_resnet_wo_attn__ssim_sobel_plus_l1',
#  'training_checkpoints_new/uniform_cities_resnet_wo_attn__ssim_with_sobel',
#  'training_checkpoints_new/uniform_cities_unet_attn__ssim_with_sobel',
#  'training_checkpoints_new/uniform_cities_unet_wo_attn__l1',
#  'training_checkpoints_new/uniform_cities_unet_wo_attn__ssim_with_sobel',
#  'training_checkpoints_new/uniform_cities__street_error',
#  'training_checkpoints_new/uniform_cities__weighted_kde_error']

# %%
# Store numeric results for all models except multi-gan

loss_functions = [[l1_loss], [l1_smooth_loss], [l2_loss], [ssim_loss, l1_loss], [ssim_loss, l1_smooth_loss], [ssim_loss, sobel_loss, l1_loss], [ssim_loss, sobel_loss],
                  [l1_loss], [l1_smooth_loss], [l2_loss], [ssim_loss, l1_loss], [ssim_loss, l1_smooth_loss], [ssim_loss, sobel_loss, l1_loss], [ssim_loss, sobel_loss],
                  [ssim_loss, sobel_loss], [l1_loss], [ssim_loss, sobel_loss]]

for i in range(len(checkpoint_paths)):
    if(checkpoint_names[i] == 'uniform_cities_multi_gan_attn__ssim_with_sobel'):
        continue

    print(checkpoint_names[i])
    tf.keras.backend.clear_session()

    # parse checkpoint name to get model type, attn, loss function
    checkpoint_name = checkpoint_names[i]
    _attn = False if 'wo_attn' in checkpoint_name else True
    gen = 'resnet9' if 'resnet' in checkpoint_name else 'unet'

    down_stack, up_stack = get_generator_arch(gen, attn = _attn)
    deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=loss_functions[i], type=gen, attention=_attn, model_name=checkpoint_name)
    deep_shadow.restore(checkpoint_paths[i])
    
    t_rmses, t_maes, t_mses, t_ssims, t_sobels = 0, 0, 0, 0, 0

    for city in test_cities:
        test = [city]
        test_dataset = get_tiles(height_path, shadow_path, test, dates, zoom, 750)
        test_dataset = test_to_tensor(test_dataset, BATCH_SIZE)

        df = pd.read_csv('data/compare_models_new/results_new_mask_height.csv')
        rmses, maes, mses, ssims,  sobels = get_metrics(test_dataset, deep_shadow.generator, latitude=lat, date=dat)
        df.loc[len(df.index)] = [checkpoint_name, city, np.average(maes), np.average(mses), np.average(rmses), np.average(ssims), np.average(sobels)] 
        df.to_csv('data/compare_models_new/results_new_mask_height.csv', index=False)

        t_rmses += np.average(rmses)
        t_maes += np.average(maes)
        t_mses += np.average(mses)
        t_ssims += np.average(ssims)
        t_sobels += np.average(sobels)
    
    print('\nAvg rmse: %.2f mae: %.2f mses: %.2f ssim: %.2f sobel: %.2f' 
          % (t_rmses/len(test_cities), t_maes/len(test_cities), t_mses/len(test_cities), 
             t_ssims/len(test_cities), t_sobels/len(test_cities)))

# %%
# Store images for all models except multi-gan

# This needs to be changed based on the number of models in training_checkpoints_new folder
# loss_functions = [[], [l1_loss], [l1_smooth_loss], [l2_loss], [ssim_loss, l1_loss], [ssim_loss, l1_smooth_loss], [ssim_loss, sobel_loss, l1_loss], [ssim_loss, sobel_loss], [ssim_loss, sobel_loss], [ssim_loss, sobel_loss], [ssim_loss, sobel_loss]]

for i in range(len(checkpoint_paths)):
    if(checkpoint_names[i] == 'uniform_cities_multi_gan_attn__ssim_with_sobel'):
        continue

    tf.keras.backend.clear_session()

    # parse checkpoint name to get model type, attn, loss function
    checkpoint_name = checkpoint_names[i]
    _attn = False if 'wo_attn' in checkpoint_name else True
    gen = 'resnet9' if 'resnet' in checkpoint_name else 'unet'

    down_stack, up_stack = get_generator_arch(gen, attn = _attn)
    deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=loss_functions[i], type=gen, attention=_attn, model_name=checkpoint_name)
    deep_shadow.restore(checkpoint_paths[i])
    
    for city in test_cities:
        test = [city]
        test_dataset = get_tiles(height_path, shadow_path, test, dates, zoom, 750)
        test_dataset = test_to_tensor(test_dataset, BATCH_SIZE)

        if not os.path.exists('data/compare_models_new/%s/%s' % (checkpoint_name, city)):
            os.makedirs('data/compare_models_new/%s/%s' % (checkpoint_name, city))

        df = pd.read_csv('data/tile_heights/%s-16.csv' %(city))
        df = df.sort_values(by=['height'], ascending=False)

        top = df.head(6)
        middle = df.iloc[len(df)//2-3:len(df)//2+3]
        bottom = df.tail(6)
        # concat
        all = pd.concat([top, middle, bottom])

        idx = 0
        for row in all.iterrows():
            i = int(row[1]['i'])
            j = int(row[1]['j'])

            if(idx < 2 or (idx > 5 and idx < 8) or (idx > 11 and idx < 14)): date = 'summer'
            elif((idx > 1 and idx < 4) or (idx > 7 and idx < 10) or (idx > 13 and idx < 16)): date = 'winter'
            else: date = 'spring'

            zoom = 16
            img_no = '%d_%d' % (i, j)

            plot_path = 'data/compare_models_new/%s/%s/%s_%s' % (checkpoint_name,city, img_no, date)
            test_on_image(deep_shadow.generator, height_path, shadow_path, city, date, zoom, i, j, path=plot_path, save=True)

            idx += 1

# %%
tf.keras.backend.clear_session()

down_stack, up_stack = get_generator_arch('resnet9', attn = False) # defined in utils

train_dataset, validation_dataset = get_train_test(
    height_path, shadow_path, train_cities, dates, zoom, TILES_PER_CITY, BATCH_SIZE, train_size =  0.95)

# %%
train_dataset = add_weights(train_dataset, BATCH_SIZE)
validation_dataset = add_weights(validation_dataset, BATCH_SIZE)

# %%
checkpoint_name = 'uniform_cities_resnet_wo_attn_weighted_ssim_sobel_loss'
checkpoint_path = 'training_checkpoints_new/%s' % (checkpoint_name)

deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=[ssim_loss, sobel_loss], type='resnet9', attention=False, weighted_loss=True, model_name=checkpoint_name)
deep_shadow.fit(checkpoint_path, train_dataset, validation_dataset, STEPS)

# %%
# 5 Fold Cross Validation

from sklearn.model_selection import KFold

cities = ['la', 'bos', 'dc', 'nyc', 'chi', 'sp', 'bue',
          'joh', 'syd', 'tok', 'par', 'mex', 'sea', 'aus']

all_dataset = get_tiles(height_path, shadow_path, cities, dates, zoom, 400)
all_dataset = np.array(all_dataset)

checkpoint_name = 'kFold'
checkpoint_path = 'training_checkpoints_new/%s' % (checkpoint_name)

kf = KFold(n_splits=5, random_state=42, shuffle=True)

fold = 0
for train_index, test_index in kf.split(all_dataset):
    tf.keras.backend.clear_session()
    train_dataset = all_dataset[train_index]
    train_dataset = train_to_tensor(train_dataset, BATCH_SIZE)

    down_stack, up_stack = get_generator_arch('resnet9', attn = False)
    deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=True, date=True, loss_funcs=[ssim_loss, sobel_loss, l1_loss], type='resnet9', attention=False, model_name=checkpoint_name)
    deep_shadow.fit(checkpoint_path+'/fold_'+str(fold), train_dataset, None, STEPS)

    deep_shadow.restore(checkpoint_path+'/fold_'+str(fold))
    test_dataset = all_dataset[test_index]
    test_dataset = test_to_tensor(test_dataset, BATCH_SIZE)
    rmses, maes, mses, ssims, sobels = get_metrics(test_dataset, deep_shadow.generator, latitude=True, date=True)

    print('\nFold: %d rmse: %.2f mae: %.2f mse: %.2f ssim: %.2f sobel: %.2f ' %
          (fold, np.average(rmses), np.average(maes), np.average(mses), np.average(ssims), np.average(sobels)))
    df = pd.DataFrame({'rmse': rmses, 'mae': maes, 'mse': mses, 'ssim': ssims, 'sobel': sobels})

    filepath = 'results/%s-%d/fold_%d.csv' % (checkpoint_name, zoom, fold)
    if not os.path.exists(os.path.dirname(filepath)):
        os.mkdir(os.path.dirname(filepath))

    df.to_csv(filepath, index=False, header=True)

    fold += 1
# Out:
# Time taken for 1000 steps: 30.95 sec
#
# Step: 39k
# custom_loss_func:  0.522235513
# gan_loss:  0.296910584
# disc_loss:  1.76069379
# ....................................................................................................
# Fold: 4 rmse: 0.06 mae: 0.03 mse: 0.01 ssim: 0.11 sobel: 0.04

# %%
for i in range(5):
    df = pd.read_csv('results/kFold-16/fold_%d.csv'%(i))
    df['ssim'] = df['ssim'].apply(lambda x: float(x.replace("tf.Tensor(", "").replace(", shape=(), dtype=float32)", "")))
    df['sobel'] = df['sobel'].apply(lambda x: float(x.replace("tf.Tensor(", "").replace(", shape=(), dtype=float32)", "")))

    # store as csv
    df.to_csv('results/kFold-16/fold_%d.csv'%(i), index=False)

# %%
t_rmses, t_maes, t_mses, t_ssims, t_sobels = 0, 0, 0, 0, 0
for i in range(5):
    df = pd.read_csv('results/kFold-16/fold_%d.csv'%(i))
    t_rmses += np.average(df['rmse'])
    t_maes += np.average(df['mae'])
    t_mses += np.average(df['mse'])
    t_ssims += np.average(df['ssim'])
    t_sobels += np.average(df['sobel'])
    print('\nFold: %d rmse: %.4f mae: %.4f mse: %.4f ssim: %.2f sobel: %.4f ' %
            (i, np.average(df['rmse']), np.average(df['mae']), np.average(df['mse']), np.average(df['ssim']), np.average(df['sobel'])))

print('\nAvg rmse: %.4f mae: %.4f mse: %.4f ssim: %.2f sobel: %.4f ' %
        (t_rmses/5, t_maes/5, t_mses/5, t_ssims/5, t_sobels/5))
# Out:
# Fold: 0 rmse: 0.0603 mae: 0.0262 mse: 0.0059 ssim: 0.10 sobel: 0.0343
#
# Fold: 1 rmse: 0.0630 mae: 0.0279 mse: 0.0062 ssim: 0.10 sobel: 0.0361
#
# Fold: 2 rmse: 0.0619 mae: 0.0267 mse: 0.0060 ssim: 0.10 sobel: 0.0361
#
# Fold: 3 rmse: 0.0663 mae: 0.0290 mse: 0.0067 ssim: 0.11 sobel: 0.0384
#
# Fold: 4 rmse: 0.0641 mae: 0.0283 mse: 0.0065 ssim: 0.11 sobel: 0.0363
#
# Avg rmse: 0.0631 mae: 0.0276 mse: 0.0063 ssim: 0.10 sobel: 0.0362

# %%
# One last model with street level error!

tf.keras.backend.clear_session()
down_stack, up_stack = get_generator_arch('resnet9', attn = False) # defined in utils

train_dataset, validation_dataset = get_train_test(
    height_path, shadow_path, train_cities, dates, zoom, TILES_PER_CITY, BATCH_SIZE, train_size =  0.95)

checkpoint_name = 'uniform_cities__street_error'
checkpoint_path = 'training_checkpoints_new/%s' % (checkpoint_name)

deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=[ssim_loss, sobel_loss, l1_loss], type='resnet9', attention=False, model_name=checkpoint_name)
deep_shadow.fit(checkpoint_path, train_dataset, validation_dataset, STEPS)
# Out:
# Time taken for 1000 steps: 106.86 sec
# Step: 39k
# custom_loss_func:  0.259346843
# gan_loss:  1.39470363
# disc_loss:  1.11055207
# street_loss:  0.0013525174
# ....................................................................................................

# %%
import scipy

files = glob.glob('data/heights_new/*')
cities = [filepath.split('\\')[1] for filepath in files]

zoom = 16
heights = []

# Find max and min tile heights for each city
for city in cities:    
    df = pd.read_csv('data/tile_heights/%s-%d.csv' % (city, zoom))
    results = []

    # add all heights to a list
    heights.extend(df['height'].tolist())

kde = scipy.stats.gaussian_kde(heights)
kde_values = kde(heights)
min_kde = min(kde_values)
max_kde = max(kde_values)

# kde_values = (kde_values - min(kde_values)) / (max(kde_values) - min(kde_values)) * 0.95

# %%
# One last model with street level error!

tf.keras.backend.clear_session()
down_stack, up_stack = get_generator_arch('resnet9', attn = False) # defined in utils

train_dataset, validation_dataset = get_train_test(
    height_path, shadow_path, train_cities, dates, zoom, TILES_PER_CITY, BATCH_SIZE, train_size =  0.95)

checkpoint_name = 'uniform_cities__weighted_kde_error'
checkpoint_path = 'training_checkpoints_new/%s' % (checkpoint_name)

deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=[ssim_loss, sobel_loss, l1_loss], type='resnet9', attention=False, model_name=checkpoint_name, kde_func=kde, min_kde=min_kde, max_kde=max_kde)
deep_shadow.fit(checkpoint_path, train_dataset, validation_dataset, STEPS)

# %%
tf.keras.backend.clear_session()

_attn = False
gen = 'resnet9'

down_stack, up_stack = get_generator_arch(gen, attn = _attn)
deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=[ssim_loss, sobel_loss, l1_loss], type=gen, attention=_attn)
deep_shadow.restore('training_checkpoints_new/uniform_cities__street_error')

t_rmses, t_maes, t_mses, t_ssims, t_sobels = 0, 0, 0, 0, 0

for city in test_cities:
    test = [city]
    test_dataset = get_tiles(height_path, shadow_path, test, dates, zoom, 750)
    test_dataset = test_to_tensor(test_dataset, BATCH_SIZE)

    df = pd.read_csv('data/compare_models_new/results_new_mask_height.csv')
    rmses, maes, mses, ssims,  sobels = get_metrics(test_dataset, deep_shadow.generator, latitude=lat, date=dat)
    
    print('\nCity: %s rmse: %.2f mae: %.2f mse: %.2f ssim: %.2f sobel: %.2f ' %
          (city, np.average(rmses), np.average(maes), np.average(mses), np.average(ssims), np.average(sobels)))
    
    df.loc[len(df.index)] = [checkpoint_name, city, np.average(rmses), np.average(maes), np.average(mses), np.average(sobels), np.average(ssims)] 
    df.to_csv('data/compare_models_new/results_new_mask_height.csv', index=False)

    t_rmses += np.average(rmses)
    t_maes += np.average(maes)
    t_mses += np.average(mses)
    t_ssims += np.average(ssims)
    t_sobels += np.average(sobels)

    

print('\nAvg rmse: %.2f mae: %.2f mses: %.2f ssim: %.2f sobel: %.2f' 
        % (t_rmses/len(test_cities), t_maes/len(test_cities), t_mses/len(test_cities), 
            t_ssims/len(test_cities), t_sobels/len(test_cities)))
# Out:
# City: dc rmse: 0.08 mae: 0.04 mse: 0.01 ssim: 0.13 sobel: 0.06
#
# City: nyc rmse: 0.08 mae: 0.04 mse: 0.01 ssim: 0.12 sobel: 0.05
#
# City: joh rmse: 0.03 mae: 0.01 mse: 0.00 ssim: 0.12 sobel: 0.01
#
# City: bue rmse: 0.04 mae: 0.01 mse: 0.00 ssim: 0.09 sobel: 0.01
#
# City: bos rmse: 0.07 mae: 0.03 mse: 0.01 ssim: 0.10 sobel: 0.05
#
# City: sea rmse: 0.06 mae: 0.03 mse: 0.00 ssim: 0.12 sobel: 0.03
#
# City: tok rmse: 0.08 mae: 0.04 mse: 0.01 ssim: 0.20 sobel: 0.05
#
# Avg rmse: 0.06 mae: 0.03 mses: 0.01 ssim: 0.12 sobel: 0.04

# %%
tf.keras.backend.clear_session()

_attn = False
gen = 'resnet9'
checkpoint_name = 'uniform_cities__street_error'

down_stack, up_stack = get_generator_arch(gen, attn = _attn)
deep_shadow = DeepShadow(512, 512, down_stack, up_stack, latitude=lat, date=dat, loss_funcs=[ssim_loss, sobel_loss, l1_loss], type=gen, attention=_attn)
deep_shadow.restore('training_checkpoints_new/uniform_cities__street_error')

for city in test_cities:
    test = [city]
    test_dataset = get_tiles(height_path, shadow_path, test, dates, zoom, 750)
    test_dataset = test_to_tensor(test_dataset, BATCH_SIZE)

    if not os.path.exists('data/compare_models_new/%s/%s' % (checkpoint_name, city)):
        os.makedirs('data/compare_models_new/%s/%s' % (checkpoint_name, city))

    df = pd.read_csv('data/tile_heights/%s-16.csv' %(city))
    df = df.sort_values(by=['height'], ascending=False)

    top = df.head(6)
    middle = df.iloc[len(df)//2-3:len(df)//2+3]
    bottom = df.tail(6)
    # concat
    all = pd.concat([top, middle, bottom])

    idx = 0
    for row in all.iterrows():
        i = int(row[1]['i'])
        j = int(row[1]['j'])

        if(idx < 2 or (idx > 5 and idx < 8) or (idx > 11 and idx < 14)): date = 'summer'
        elif((idx > 1 and idx < 4) or (idx > 7 and idx < 10) or (idx > 13 and idx < 16)): date = 'winter'
        else: date = 'spring'

        zoom = 16
        img_no = '%d_%d' % (i, j)

        plot_path = 'data/compare_models_new/%s/%s/%s_%s' % (checkpoint_name, city, img_no, date)
        test_on_image(deep_shadow.generator, height_path, shadow_path, city, date, zoom, i, j, path=plot_path, save=True)
