# %%
import os
os.environ['USE_PYGEOS'] = '0'

import geopandas as gpd
import matplotlib.pyplot as plt

# %%
stats = gpd.read_feather('./data/metrics/streets_lon-winter_0-025.feather')

# %%
stats
# Out:
#              min       max      mean  count        sum    median  nodata  \
# 0       0.000000  0.007843  0.002440     90   0.219608  0.003922       0
# 1       0.000000  0.250980  0.096242    144  13.858824  0.133333     126
# 2       0.000000  0.250980  0.022975   1457  33.474510  0.000000    1032
# 3       0.000000  0.250980  0.062141    669  41.572549  0.054902     422
# 4       0.035294  0.062745  0.049530     73   3.615686  0.050980       0
# ...          ...       ...       ...    ...        ...       ...     ...
# 290932  0.000000  0.000000  0.000000     80   0.000000  0.000000     189
# 290933  0.000000  0.250980  0.136754     94  12.854902  0.149020     123
# 290934  0.000000  0.000000  0.000000     30   0.000000  0.000000      13
# 290935  0.000000  0.000000  0.000000      4   0.000000  0.000000     114
# 290936  0.043137  0.250980  0.154787    221  34.207843  0.145098     155
#
#                area              name  \
# 0        195.939361     Ballards Lane
# 1        542.986370         High Road
# 2       5445.877158     East End Road
# 3       2407.848868  Cockfosters Road
# 4        156.314306       Western Way
# ...             ...               ...
# 290932   592.576832              <NA>
# 290933   481.253297              <NA>
# 290934    95.381575              <NA>
# 290935   262.992623      Scott Avenue
# 290936   833.830022      Scott Avenue
#
#                                                  geometry
# 0       MULTILINESTRING ((-0.19312 51.60172, -0.19297 ...
# 1       MULTILINESTRING ((-0.17679 51.61732, -0.17679 ...
# 2       MULTILINESTRING ((-0.19799 51.59712, -0.19778 ...
# 3       MULTILINESTRING ((-0.16075 51.67152, -0.16070 ...
# 4       MULTILINESTRING ((-0.18865 51.64062, -0.18862 ...
# ...                                                   ...
# 290932  MULTILINESTRING ((-0.13644 51.61087, -0.13615 ...
# 290933  MULTILINESTRING ((-0.13509 51.61143, -0.13512 ...
# 290934  MULTILINESTRING ((0.10356 51.44173, 0.10358 51...
# 290935  MULTILINESTRING ((-0.20936 51.45195, -0.20944 ...
# 290936  MULTILINESTRING ((-0.21064 51.45208, -0.21068 ...
#
# [287983 rows x 10 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
stats.plot(column='median', ax=ax, legend=True)
# Out:
# <AxesSubplot:>
